# %% [markdown]
# # Te damos la bienvenida a Colab

# %%
print("Operadores Matematicos")
print("Realiza la suma 4 + 4 =" , 4 + 4)
print("Realiza la resta 8 - 6 =" , 8 - 6)
# Out:
# Operadores Matematicos
# Realiza la suma 4 + 4 = 8
# Realiza la resta 8 - 6 = 2

# %%
print("realiza la multiplicacon de 5 * 4 =" , 5 * 4)
print("realiza la multiplicacion de 3 * 3 =" , 3 * 3)
print("realiza la multiplicacion de 4 * 4 =" , 4 * 4 )
print("realiza la multiplicacion 5 * 5 =" , 5 * 5)
print("realiza la multiplicacion 6 * 6 =" , 6 * 6)
print("realiza la multiplicacion 7 * 7 =" , 7 * 7)
print("realiza la multiplicacion 8 * 8 =" , 8 * 8)
print("realiza la multiplicacion 9 * 9 =" , 9 * 9)
print("realiza la multiplicacion 1 * 1 =" , 1 * 1)
print("realiza la multiplicacion 2 * 2 =" , 2 * 2)
# Out:
# realiza la multiplicacon de 5 * 4 = 20
# realiza la multiplicacion de 3 * 3 = 9
# realiza la multiplicacion de 4 * 4 = 16
# realiza la multiplicacion 5 * 5 = 25
# realiza la multiplicacion 6 * 6 = 36
# realiza la multiplicacion 7 * 7 = 49
# realiza la multiplicacion 8 * 8 = 64
# realiza la multiplicacion 9 * 9 = 81
# realiza la multiplicacion 1 * 1 = 1
# realiza la multiplicacion 2 * 2 = 4

# %%
print("realiza la suma de 4 + 4 =" , 4 + 4)
print("realiza la suma 3 + 3 =" , 3 + 3)
print("realiza la suma 2 + 2 =" , 3 + 4)
print("realiza la suma 1 + 1 =" , 1 + 2)
print("realiza la suma 6 + 9 =" , 6 + 9)
print("realia la suma 9 + 9" , 9 + 9)
print("realiza la suma 6 + 5 =" , 6 +5)
print("realiza la suma 7 + 9 =" , 7 + 8)
print("realiza la suma 9 + 6 =" , 9 + 6)
print("realiza la suma 5 + 5 =" , 5 +5)
# Out:
# realiza la suma de 4 + 4 = 8
# realiza la suma 3 + 3 = 6
# realiza la suma 2 + 2 = 7
# realiza la suma 1 + 1 = 3
# realiza la suma 6 + 9 = 15
# realia la suma 9 + 9 18
# realiza la suma 6 + 5 = 11
# realiza la suma 7 + 9 = 15
# realiza la suma 9 + 6 = 15
# realiza la suma 5 + 5 = 10

# %%
print("realiza la resta 8 - 7 =" , 8 - 7)
print("reliza la resta 9 - 6 =" , 9 - 6)
print("realiza la resta 7 - 1 =" , 7 - 1)
print("realiza la resta 8 - 5 =" , 8 - 5)
print("realiza la resta 2 - 1 =" , 2 - 1)
print("realiza la resta 5 - 3 =" , 5 - 3)
print("realiza la resta 6 - 4 =" , 6 - 4)
print("realiza la resta 5 - 3 =" , 5 - 3)
print("realiza la resta 10 - 7 =" , 10 - 7)
print("realiza la resta 50 - 25 =" , 50 - 25)
# Out:
# realiza la resta 8 - 7 = 1
# reliza la resta 9 - 6 = 3
# realiza la resta 7 - 1 = 6
# realiza la resta 8 - 5 = 3
# realiza la resta 2 - 1 = 1
# realiza la resta 5 - 3 = 2
# realiza la resta 6 - 4 = 2
# realiza la resta 5 - 3 = 2
# realiza la resta 10 - 7 = 3
# realiza la resta 50 - 25 = 25

# %%
print("realiza la division 50 / 2 =" , 50 / 2)
print("realiza la division 100 / 3 =" , 100 / 3)
print("realiza la division 900 / 2 =" , 900 / 2)
print("realiza la division 500 / 6 =" , 500 / 6)
print("realiza la division 700 / 4 =" , 700 / 4)
print("realiza la division 150 / 5 =" , 150 / 5)
print("realiza la division 30 / 3 =" , 30 / 3)
print("realiza la division 50 / 6 =" , 50 / 6)
print("realiza la division 80 / 2 =" , 80 / 2)
print("realiza la division 850 / 6 =" , 850 / 6)
# Out:
# realiza la division 50 / 2 = 25.0
# realiza la division 100 / 3 = 33.333333333333336
# realiza la division 900 / 2 = 450.0
# realiza la division 500 / 6 = 83.33333333333333
# realiza la division 700 / 4 = 175.0
# realiza la division 150 / 5 = 30.0
# realiza la division 30 / 3 = 10.0
# realiza la division 50 / 6 = 8.333333333333334
# realiza la division 80 / 2 = 40.0
# realiza la division 850 / 6 = 141.66666666666666
